# %%
from download_channel import download_whole_channel
from ifttt import send_text

# %%
GavinWebber
PureLivingForLife
NurdRage
WilliamOsman
CognitiveClass
UrbanFarmerCurtisStone
CGPGrey
Kurzgesagt

channels = ['NightHawkInLight','AppliedScience','KingOfRandom','SchoolOfLife','BingingWithBabish']

download_whole_channel('GreatScott', folder='D:/YouTube')
download_whole_channel('HomeMadeModern', folder='D:/YouTube')
download_whole_channel('HowToMakeEveryThing', folder='D:/YouTube')

nilered
codyslab
primitivetechnology
3blue1brown

# %%
channels = ['GavinWebber','PureLivingForLife','NurdRage','WilliamOsman','CognitiveClass','UrbanFarmerCurtisStone','CGPGrey','Kurzgesagt']
for ch in channels:
    try:
        download_whole_channel(ch, folder='D:/YouTube', verbose=False)
        msg = 'Finished downloading {}!'.format(ch)
        print(msg)
        send_text(msg)
    except Exception as e:
        msg = 'Failed to download {} with error: {}'.format(ch, e)
        print(msg)
        send_text(msg)
send_text('Put down that cocktail!')
# Out:
# Failed to get video with url http://www.youtube.com/watch?v=OaPHMK0_T0o
# Failed to get video with url http://www.youtube.com/watch?v=RpscG-rmwY4
# Failed to get video with url http://www.youtube.com/watch?v=tUH6BRaiWLA
# Finished downloading GavinWebber!
# Failed to download file with exception: HTTP Error 500: Internal Server Error

# %%
download_whole_channel('SchoolOfLife', folder='D:/YouTube')
# Out:
# Failed to download file with exception: Conflicting filename:'PHILOSOPHY - The Stoics yu7n0XzqtfA'
# Failed to download file with exception: Conflicting filename:'PHILOSOPHY - Nietzsche wHWbZmg2hzU'
# Failed to download file with exception: Conflicting filename:'Why We Go Off People Who Like Us BqyChjVdM3E'
# Failed to download file with exception: Conflicting filename:'How to Find Fulfilling Work veriqDHLXsw'
# Failed to download file with exception: Conflicting filename:'PHILOSOPHY - Epicurus Kg_47J6sy3A'
# Failed to download file with exception: Conflicting filename:'NIETZSCHE ON - The Superman bxiKqA-u8y4'
# Failed to download file with exception: Conflicting filename:'How to Handle Crushes 88q8XDJKZVs'
# Failed to download file with exception: Conflicting filename:'On Feeling Melancholy PaZ1EmPOE_k'
# Failed to download file with exception: Conflicting filename:'PHILOSOPHY - Albert Camus jQOfbObFOCw'
# ...
